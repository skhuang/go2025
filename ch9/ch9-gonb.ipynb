// %% [markdown]
// <h1>Table of Contents<span class="tocSkip"></span></h1>
// <div class="toc"><ul class="toc-item"><li><span><a href="#Concurrency-with-Shared-Variables" data-toc-modified-id="Concurrency-with-Shared-Variables-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Concurrency with Shared Variables</a></span><ul class="toc-item"><li><span><a href="#Race-Conditions" data-toc-modified-id="Race-Conditions-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Race Conditions</a></span></li><li><span><a href="#Mutual-Exclusion:-sync.Mutex" data-toc-modified-id="Mutual-Exclusion:-sync.Mutex-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>Mutual Exclusion: sync.Mutex</a></span></li><li><span><a href="#Read/Write-Mutexes:-sync.RWMutex" data-toc-modified-id="Read/Write-Mutexes:-sync.RWMutex-9.3"><span class="toc-item-num">9.3&nbsp;&nbsp;</span>Read/Write Mutexes: sync.RWMutex</a></span></li><li><span><a href="#Memory-Synchronization" data-toc-modified-id="Memory-Synchronization-9.4"><span class="toc-item-num">9.4&nbsp;&nbsp;</span>Memory Synchronization</a></span></li><li><span><a href="#Lazy-Initialization:-sync.Once" data-toc-modified-id="Lazy-Initialization:-sync.Once-9.5"><span class="toc-item-num">9.5&nbsp;&nbsp;</span>Lazy Initialization: sync.Once</a></span></li><li><span><a href="#The-Race-Detector" data-toc-modified-id="The-Race-Detector-9.6"><span class="toc-item-num">9.6&nbsp;&nbsp;</span>The Race Detector</a></span></li><li><span><a href="#Example:-Concurrent-Non-Blocking-Cache" data-toc-modified-id="Example:-Concurrent-Non-Blocking-Cache-9.7"><span class="toc-item-num">9.7&nbsp;&nbsp;</span>Example: Concurrent Non-Blocking Cache</a></span><ul class="toc-item"><li><span><a href="#memo2-with-sync.Mutex,-but-with-no-performance-gains" data-toc-modified-id="memo2-with-sync.Mutex,-but-with-no-performance-gains-9.7.1"><span class="toc-item-num">9.7.1&nbsp;&nbsp;</span>memo2 with sync.Mutex, but with no performance gains</a></span></li></ul></li><li><span><a href="#Goroutines-and-Threads" data-toc-modified-id="Goroutines-and-Threads-9.8"><span class="toc-item-num">9.8&nbsp;&nbsp;</span>Goroutines and Threads</a></span><ul class="toc-item"><li><span><a href="#Growable-Stacks" data-toc-modified-id="Growable-Stacks-9.8.1"><span class="toc-item-num">9.8.1&nbsp;&nbsp;</span>Growable Stacks</a></span></li><li><span><a href="#Groroutine-Scheduling" data-toc-modified-id="Groroutine-Scheduling-9.8.2"><span class="toc-item-num">9.8.2&nbsp;&nbsp;</span>Groroutine Scheduling</a></span></li><li><span><a href="#GOMAXPROCS" data-toc-modified-id="GOMAXPROCS-9.8.3"><span class="toc-item-num">9.8.3&nbsp;&nbsp;</span>GOMAXPROCS</a></span></li><li><span><a href="#Goroutines-Have-No-Identify" data-toc-modified-id="Goroutines-Have-No-Identify-9.8.4"><span class="toc-item-num">9.8.4&nbsp;&nbsp;</span>Goroutines Have No Identify</a></span></li></ul></li></ul></li></ul></div>

// %% [markdown]
// # Concurrency with Shared Variables

// %% [markdown]
// ## Race Conditions

// %%
var balance int
func Deposit(amount int) {  balance = balance + amount }
func Balance() int {return  balance }

// %%
// Alice:
import ("time";"fmt")
%%
//go Deposit(100)
//go Deposit(200)
go func() {
    Deposit(100)
    fmt.Println("in B =", Balance()) 
}()

//Alice
go func() {
    Deposit(200)                  // A1
    fmt.Println("=", Balance())   // A2
}()
//Bob:

//go func() {
//    Deposit(100)                  //B
//    fmt.Println("in B =", Balance()) 
//}()

time.Sleep(100* time.Millisecond)//delay termination
//fmt.Println("Final After sleep =", Balance())
// Out:
// in B = 100
// = 300

// %%
%%
for i:=0; i<100; i++ {
    balance=0
    for j :=0; j<100; j++ {
      go Deposit(4)
        //Deposit(1)
    }
    time.Sleep(100* time.Millisecond)
    fmt.Println("=",Balance())
}
// Out:
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 396
// = 352
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 376
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 372
// = 400
// = 400
// = 400
// = 400
// = 380
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 376
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 392
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400

// %%
%%
var x []int
go func() { x = make([]int,10)}()
go func() { x = make([]int,1000000)}()

time.Sleep(1* time.Millisecond)
x[999999] = 1 // Note: undefined behavior; memory corruption possible
// Out:
// panic: runtime error: index out of range [999999] with length 10
//
// goroutine 1 [running]:
// main.main()
// 	 [[ Cell [114] Line 7 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_62a9c60b/main.go:24 +0x144
// exit status 2

// %% [markdown]
// * A data race occurs whenever two goroutines access the same variable concurrently and at least one of the accesses is a write
// * Three ways to avoid a data race
//   * The first way: not to write the variable
//   * The second way: avoid acessing the variable from multiple goroutines
//     * Do not communicate by sharing memory; share memory by communicating
//   * The third way: allow many goroutines to access the variable, but only one at a time
//     * mutual exclusion

// %%
// The first way:not to write the variable
// There is a data race accessing the map
import "image"
var icons = make(map[string]image.Image)
func loadIcon(name string) image.Image
// not concurrency-safe
func Icon(name string) image.Image {
    icon, ok := icons[name]
    if !ok {
        icon = loadIcon(name)
        icons[name] = icon
    }
    return icon
}
// Out:
// <style>
// .gonb-err-location {
// 	background: var(--jp-err-color2);
// 	border-radius: 3px;
// 	border-style: dotted;
// 	border-width: 1px;
// 	border-color: var(--jp-border-color2);
// }
// .gonb-err-location:hover {
// 	border-width: 2px;
// 	border-style: solid;
// 	border-color: var(--jp-border-color2);
// }
// .gonb-err-context {
// 	display: none;
// }
// .gonb-err-location:hover + .gonb-err-context {
// 	background: var(--jp-dialog-background);
// 	border-radius: 3px;
// 	border-style: solid;
// 	border-width: 1px;
// 	border-color: var(--jp-border-color2);
// 	display: block;
// 	white-space: pre;
// 	font-family: monospace;
// }
// .gonb-err-line {
// 	border-radius: 3px;
// 	border-style: dotted;
// 	border-width: 1px;
// 	border-color: var(--jp-border-color2);
// 	background-color: var(--jp-rendermime-err-background);
// 	font-weight: bold;
// }
// .gonb-cell-line-info {
// 	background: var(--jp-layout-color2);
// 	color: #999;
// 	margin: 0.1em;
// 	border: 1px solid var(--jp-border-color1);
// 	padding-left: 0.2em;
// 	padding-right: 0.2em;
// }
// </style>
// <div class="lm-Widget p-Widget lm-Panel p-Panel jp-OutputArea-child">
// <div class="lm-Widget p-Widget jp-RenderedText jp-mod-trusted jp-OutputArea-output" data-mime-type="application/vnd.jupyter.stderr" style="font-family: monospace;">
//
//
// <span style="white-space: pre;"> # gonb_62a9c60b</span>
//
// <br/>
//
// <span class="gonb-cell-line-info">Cell[115]: Line 5</span>
// <span class="gonb-err-location">./main.go:26:6: </span> missing function body
// <div class="gonb-err-context">
//     return icon
// }
//
// <div class="gonb-err-line">func loadIcon(name string) image.Image
// </div>
//
//
// </div>
//
// <br/>
//
//
// <span style="white-space: pre;"> </span>
//
// <br/>
//
// </div>
// failed to run "/opt/homebrew/bin/go build -o /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_62a9c60b/gonb_62a9c60b": exit status 1

// %%
// initialize the map with all necessary entries before creating goroutines and never modify again
// any goroutings may safely call Icon concurrently, only reads the map
import "image"
var icons = map[string]image.Image {
    "spades.png":  loadIcon("spades.png"),
    "hearts.png":  loadIcon("hearts.png"),
    "diamonds.png":loadIcon("diamonds.png"),
    "clubs.png":   loadIcon("clubs.png"),
}
// Concurrency-safe,
func Icon(name string) image.Image {return icons[name]}

// %% [markdown]
// * The second way
//   * Use a channel to send the confining goroutine a request to query or update the variable
//     * monitor goroutine: broker access to a confined variable using channel requests

// %%
//gopl.io/ch9/bank1
// Copyright © 2016 Alan A. A. Donovan & Brian W. Kernighan.
// License: https://creativecommons.org/licenses/by-nc-sa/4.0/

// See page 261.
//!+

// Package bank provides a concurrency-safe bank with one account.
//package bank

var deposits = make(chan int) // send amount to deposit
var balances = make(chan int) // receive balance

func Deposit(amount int) { deposits <- amount }
func Balance() int       { return <-balances }

func teller() {
	var balance int // balance is confined to teller goroutine
	for {
		select {
		case amount := <-deposits:
			balance += amount
		case balances <- balance:
		}
	}
}

func init() {
	go teller() // start the monitor goroutine
}

//!-

// %%
//back_test
// Copyright © 2016 Alan A. A. Donovan & Brian W. Kernighan.
// License: https://creativecommons.org/licenses/by-nc-sa/4.0/

//package bank_test

import (
	"fmt"
	"testing"

	"gopl.io/ch9/bank1"
)

func TestBank(t *testing.T) {
	done := make(chan struct{})

	// Alice
	go func() {
		bank.Deposit(200)
		fmt.Println("=", bank.Balance())
		done <- struct{}{}
	}()

	// Bob
	go func() {
		bank.Deposit(100)
		done <- struct{}{}
	}()

	// Wait for both transactions.
	<-done
	<-done

	if got, want := bank.Balance(), 300; got != want {
		t.Errorf("Balance = %d, want %d", got, want)
	}
}

// %%
%%
var t testing.T
TestBank(&t)
// Out:
// = 300

// %%
import (
	"fmt"
	"testing"
	"gopl.io/ch9/bank1"
)
%%
done := make(chan struct{})
for j :=0; j<200; j++ {
    go func() {
        bank.Deposit(4)
       //Deposit(1)
        done <- struct{}{}
    }()
}
for i:= 0; i <200; i++ {
    <-done
}
//time.Sleep(400* time.Millisecond)
fmt.Println("=",bank.Balance())
//time.Sleep(400* time.Millisecond)
// Out:
// = 800

// %%
import "fmt"
type Cake struct {state string}
func baker(cooked chan <- *Cake) {
    for {
      cake := new(Cake)
      cake.state = "cooked"
      fmt.Println(cake.state)
      cooked <- cake // baker never touches this cake again
    }
}

func icer(iced chan <- *Cake, cooked <- chan *Cake){
    for cake := range cooked {
        cake.state = "iced"
        fmt.Println(cake.state)
        iced <- cake //icer never touches this cake again
    }
}

// %%
// Cakes are serially confied, first to the baker, then to the icer
import "time"
%%
cooked := make(chan *Cake,10)
iced := make(chan *Cake,20)
go icer(iced, cooked)
go baker(cooked)
time.Sleep(5* time.Millisecond)
// Out:
// cooked
// cooked
// cooked
// cooked
// cooked
// cooked
// cooked
// cooked
// cooked
// cooked
// cooked
// iced
// iced
// iced
// iced
// iced
// iced
// iced
// iced
// iced
// iced
// iced
// cooked
// cooked
// cooked
// cooked
// cooked
// cooked
// cooked
// cooked
// cooked
// cooked
// cooked
// cooked
// iced
// iced
// iced
// iced
// iced
// iced
// iced
// iced
// iced
// iced
// cooked
// cooked
// cooked
// cooked
// cooked
// cooked
// cooked
// cooked
// cooked

// %% [markdown]
// ## Mutual Exclusion: sync.Mutex

// %%
//gopl.io/ch9/bank2
var (
    sema = make (chan struct{},1)
    balance int
)
func Deposit(amount int) {
    sema <- struct{}{} // acquire token
    balance = balance + amount
    <- sema  //release token
}
func Balance() int {
    //sema <- struct{}{} // acquire token
    b := balance
    //<- sema // release token
    return b
}

// %%
%%
done := make(chan struct{})
for i:=0; i<100; i++ {
    balance=0
    for j :=0; j<100; j++ {
      //go Deposit(4)
        go func() {
          Deposit(4)
       // Deposit(1)
          done <- struct{}{}
        }()
    }
    for i:= 0; i <100; i++ {
      <-done
    }
    //time.Sleep(100* time.Millisecond)
    fmt.Println("=",Balance())
}
// Out:
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400

// %%
//gopl.io/ch9/bank3
import "sync"
var (
  mu sync.Mutex //guards balance
  balance int
)

func Deposit(amount int) {
    mu.Lock()
    balance = balance + amount
    mu.Unlock()
}
func Balance() int {
    mu.Lock()
    b := balance
    mu.Unlock()
    return b
}

// %%
import ("time";"fmt")
%%
done := make(chan struct{})
for i:=0; i<100; i++ {
    balance=0
    for j :=0; j<100; j++ {
        go func() {
          Deposit(4)
          done <- struct{}{}
        }()
    }
    for i:= 0; i <100; i++ {
      <-done
    }
    time.Sleep(100* time.Millisecond)
    fmt.Println("=",Balance())
}
// Out:
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400
// = 400

// %%
func Balance() int {
    mu.Lock()
    defer mu.Unlock()
    return balance
}

// %% [markdown]
// * Withdraw function, three implementation
//   * without lock
//   * lock a second time and lead to a deadlock
//   * internal implementation without second lock

// %%
// Not Atomic
func Withdraw(amount int) bool {
    Deposit(-amount)
    time.Sleep(5 * time.Millisecond)
    if Balance() < 0 {
        Deposit(amount)
        return false // insufficient funds
    }
    return true
}

// %%
import ("time";"fmt";"sync")
var (
  n sync.WaitGroup 
  balance int
)

%% GOMAXPROC=4
//done := make(chan struct{})
  for i:=0; i<100; i++ {
    balance=600
    for j :=0;j<100; j++ {
        n.Add(2)
        
        go func() {
          Deposit(5)
          n.Done()
          //done <- struct{}{}
        }()
        go func() {
          Withdraw(10)
          //done <- struct{}{}
          n.Done()
        }()
        //go Deposit(5)
        //go Withdraw(2)   
    }
    //for i:= 0; i <100; i++ {
    //  <-done
    //}
    //time.Sleep(300* time.Millisecond)
    n.Wait()
    fmt.Println("=",Balance())
  }
// Out:
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100

// %%
// incorrect, may be a deadlock
func Withdraw(amount int) bool {
    mu.Lock()
    defer mu.Unlock()
    Deposit(-amount) 
    if Balance() < 0 {
        Deposit(amount)
        return false // insufficient funds
    }
    return true
}

// %%
import ("time";"fmt")
%%
//done := make(chan struct{})
for i:=0; i<10; i++ {
    balance=0
    for j :=0; j<100; j++ {
      go Deposit(4)
      go Withdraw(2)
    }
    time.Sleep(100* time.Millisecond)
    fmt.Println("=",Balance())
}
// Out:
// fatal error: all goroutines are asleep - deadlock!
//
// goroutine 1 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0xa6ab3d4a?, 0xe0?, 0x1400007ae88?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Balance()
// 	 [[ Cell [182] Line 23 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:32 +0x90
// main.main()
// 	 [[ Cell [316] Line 11 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:92 +0x74
//
// goroutine 8 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Deposit(0xfffffffffffffffe)
// 	 [[ Cell [182] Line 18 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:38 +0x90
// main.Withdraw(0x2)
// 	 [[ Cell [315] Line 5 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:71 +0xcc
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 8 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:89 +0x124
//
// goroutine 10 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Withdraw(0x2)
// 	 [[ Cell [315] Line 3 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:69 +0x94
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 8 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:89 +0x124
//
// goroutine 11 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Deposit(0x4)
// 	 [[ Cell [182] Line 18 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:38 +0x90
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 7 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:88 +0x118
//
// goroutine 12 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Withdraw(0x2)
// 	 [[ Cell [315] Line 3 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:69 +0x94
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 8 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:89 +0x124
//
// goroutine 13 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Deposit(0x4)
// 	 [[ Cell [182] Line 18 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:38 +0x90
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 7 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:88 +0x118
//
// goroutine 14 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Withdraw(0x2)
// 	 [[ Cell [315] Line 3 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:69 +0x94
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 8 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:89 +0x124
//
// goroutine 15 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Deposit(0x4)
// 	 [[ Cell [182] Line 18 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:38 +0x90
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 7 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:88 +0x118
//
// goroutine 16 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Withdraw(0x2)
// 	 [[ Cell [315] Line 3 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:69 +0x94
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 8 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:89 +0x124
//
// goroutine 17 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Deposit(0x4)
// 	 [[ Cell [182] Line 18 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:38 +0x90
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 7 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:88 +0x118
//
// goroutine 18 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Withdraw(0x2)
// 	 [[ Cell [315] Line 3 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:69 +0x94
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 8 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:89 +0x124
//
// goroutine 19 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Deposit(0x4)
// 	 [[ Cell [182] Line 18 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:38 +0x90
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 7 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:88 +0x118
//
// goroutine 20 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Withdraw(0x2)
// 	 [[ Cell [315] Line 3 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:69 +0x94
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 8 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:89 +0x124
//
// goroutine 21 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Deposit(0x4)
// 	 [[ Cell [182] Line 18 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:38 +0x90
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 7 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:88 +0x118
//
// goroutine 22 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Withdraw(0x2)
// 	 [[ Cell [315] Line 3 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:69 +0x94
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 8 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:89 +0x124
//
// goroutine 23 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Deposit(0x4)
// 	 [[ Cell [182] Line 18 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:38 +0x90
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 7 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:88 +0x118
//
// goroutine 24 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Withdraw(0x2)
// 	 [[ Cell [315] Line 3 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:69 +0x94
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 8 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:89 +0x124
//
// goroutine 25 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Deposit(0x4)
// 	 [[ Cell [182] Line 18 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:38 +0x90
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 7 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:88 +0x118
//
// goroutine 26 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Withdraw(0x2)
// 	 [[ Cell [315] Line 3 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:69 +0x94
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 8 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:89 +0x124
//
// goroutine 27 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Deposit(0x4)
// 	 [[ Cell [182] Line 18 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:38 +0x90
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 7 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:88 +0x118
//
// goroutine 28 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Withdraw(0x2)
// 	 [[ Cell [315] Line 3 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:69 +0x94
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 8 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:89 +0x124
//
// goroutine 29 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Deposit(0x4)
// 	 [[ Cell [182] Line 18 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:38 +0x90
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 7 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:88 +0x118
//
// goroutine 30 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Withdraw(0x2)
// 	 [[ Cell [315] Line 3 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:69 +0x94
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 8 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:89 +0x124
//
// goroutine 31 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Deposit(0x4)
// 	 [[ Cell [182] Line 18 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:38 +0x90
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 7 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:88 +0x118
//
// goroutine 32 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Withdraw(0x2)
// 	 [[ Cell [315] Line 3 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:69 +0x94
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 8 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:89 +0x124
//
// goroutine 33 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Deposit(0x4)
// 	 [[ Cell [182] Line 18 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:38 +0x90
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 7 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:88 +0x118
//
// goroutine 34 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Withdraw(0x2)
// 	 [[ Cell [315] Line 3 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:69 +0x94
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 8 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:89 +0x124
//
// goroutine 35 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Deposit(0x4)
// 	 [[ Cell [182] Line 18 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:38 +0x90
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 7 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:88 +0x118
//
// goroutine 36 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Withdraw(0x2)
// 	 [[ Cell [315] Line 3 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:69 +0x94
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 8 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:89 +0x124
//
// goroutine 37 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Deposit(0x4)
// 	 [[ Cell [182] Line 18 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:38 +0x90
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 7 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:88 +0x118
//
// goroutine 38 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Withdraw(0x2)
// 	 [[ Cell [315] Line 3 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:69 +0x94
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 8 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:89 +0x124
//
// goroutine 39 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Deposit(0x4)
// 	 [[ Cell [182] Line 18 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:38 +0x90
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 7 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:88 +0x118
//
// goroutine 40 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Withdraw(0x2)
// 	 [[ Cell [315] Line 3 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:69 +0x94
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 8 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:89 +0x124
//
// goroutine 41 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Deposit(0x4)
// 	 [[ Cell [182] Line 18 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:38 +0x90
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 7 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:88 +0x118
//
// goroutine 42 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Withdraw(0x2)
// 	 [[ Cell [315] Line 3 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:69 +0x94
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 8 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:89 +0x124
//
// goroutine 43 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Deposit(0x4)
// 	 [[ Cell [182] Line 18 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:38 +0x90
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 7 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:88 +0x118
//
// goroutine 44 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Withdraw(0x2)
// 	 [[ Cell [315] Line 3 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:69 +0x94
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 8 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:89 +0x124
//
// goroutine 45 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Deposit(0x4)
// 	 [[ Cell [182] Line 18 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:38 +0x90
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 7 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:88 +0x118
//
// goroutine 46 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Withdraw(0x2)
// 	 [[ Cell [315] Line 3 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:69 +0x94
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 8 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:89 +0x124
//
// goroutine 47 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Deposit(0x4)
// 	 [[ Cell [182] Line 18 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:38 +0x90
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 7 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:88 +0x118
//
// goroutine 48 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Withdraw(0x2)
// 	 [[ Cell [315] Line 3 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:69 +0x94
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 8 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:89 +0x124
//
// goroutine 49 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Deposit(0x4)
// 	 [[ Cell [182] Line 18 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:38 +0x90
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 7 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:88 +0x118
//
// goroutine 50 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Withdraw(0x2)
// 	 [[ Cell [315] Line 3 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:69 +0x94
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 8 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:89 +0x124
//
// goroutine 51 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Deposit(0x4)
// 	 [[ Cell [182] Line 18 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:38 +0x90
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 7 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:88 +0x118
//
// goroutine 52 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Withdraw(0x2)
// 	 [[ Cell [315] Line 3 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:69 +0x94
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 8 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:89 +0x124
//
// goroutine 53 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Deposit(0x4)
// 	 [[ Cell [182] Line 18 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:38 +0x90
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 7 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:88 +0x118
//
// goroutine 54 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Withdraw(0x2)
// 	 [[ Cell [315] Line 3 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:69 +0x94
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 8 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:89 +0x124
//
// goroutine 55 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Deposit(0x4)
// 	 [[ Cell [182] Line 18 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:38 +0x90
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 7 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:88 +0x118
//
// goroutine 56 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Withdraw(0x2)
// 	 [[ Cell [315] Line 3 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:69 +0x94
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 8 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:89 +0x124
//
// goroutine 57 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Deposit(0x4)
// 	 [[ Cell [182] Line 18 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:38 +0x90
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 7 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:88 +0x118
//
// goroutine 58 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Withdraw(0x2)
// 	 [[ Cell [315] Line 3 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:69 +0x94
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 8 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:89 +0x124
//
// goroutine 59 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Deposit(0x4)
// 	 [[ Cell [182] Line 18 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:38 +0x90
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 7 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:88 +0x118
//
// goroutine 60 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Withdraw(0x2)
// 	 [[ Cell [315] Line 3 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:69 +0x94
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 8 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:89 +0x124
//
// goroutine 61 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Deposit(0x4)
// 	 [[ Cell [182] Line 18 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:38 +0x90
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 7 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:88 +0x118
//
// goroutine 62 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Withdraw(0x2)
// 	 [[ Cell [315] Line 3 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:69 +0x94
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 8 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:89 +0x124
//
// goroutine 63 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Deposit(0x4)
// 	 [[ Cell [182] Line 18 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:38 +0x90
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 7 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:88 +0x118
//
// goroutine 64 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Withdraw(0x2)
// 	 [[ Cell [315] Line 3 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:69 +0x94
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 8 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:89 +0x124
//
// goroutine 65 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Deposit(0x4)
// 	 [[ Cell [182] Line 18 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:38 +0x90
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 7 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:88 +0x118
//
// goroutine 66 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Withdraw(0x2)
// 	 [[ Cell [315] Line 3 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:69 +0x94
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 8 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:89 +0x124
//
// goroutine 67 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Deposit(0x4)
// 	 [[ Cell [182] Line 18 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:38 +0x90
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 7 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:88 +0x118
//
// goroutine 68 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Withdraw(0x2)
// 	 [[ Cell [315] Line 3 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:69 +0x94
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 8 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:89 +0x124
//
// goroutine 69 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Deposit(0x4)
// 	 [[ Cell [182] Line 18 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:38 +0x90
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 7 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:88 +0x118
//
// goroutine 70 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Withdraw(0x2)
// 	 [[ Cell [315] Line 3 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:69 +0x94
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 8 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:89 +0x124
//
// goroutine 71 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Deposit(0x4)
// 	 [[ Cell [182] Line 18 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:38 +0x90
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 7 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:88 +0x118
//
// goroutine 72 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Withdraw(0x2)
// 	 [[ Cell [315] Line 3 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:69 +0x94
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 8 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:89 +0x124
//
// goroutine 73 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Deposit(0x4)
// 	 [[ Cell [182] Line 18 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:38 +0x90
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 7 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:88 +0x118
//
// goroutine 74 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Withdraw(0x2)
// 	 [[ Cell [315] Line 3 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:69 +0x94
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 8 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:89 +0x124
//
// goroutine 75 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Deposit(0x4)
// 	 [[ Cell [182] Line 18 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:38 +0x90
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 7 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:88 +0x118
//
// goroutine 76 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Withdraw(0x2)
// 	 [[ Cell [315] Line 3 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:69 +0x94
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 8 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:89 +0x124
//
// goroutine 77 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Deposit(0x4)
// 	 [[ Cell [182] Line 18 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:38 +0x90
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 7 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:88 +0x118
//
// goroutine 78 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Withdraw(0x2)
// 	 [[ Cell [315] Line 3 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:69 +0x94
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 8 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:89 +0x124
//
// goroutine 79 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Deposit(0x4)
// 	 [[ Cell [182] Line 18 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:38 +0x90
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 7 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:88 +0x118
//
// goroutine 80 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Withdraw(0x2)
// 	 [[ Cell [315] Line 3 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:69 +0x94
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 8 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:89 +0x124
//
// goroutine 81 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Deposit(0x4)
// 	 [[ Cell [182] Line 18 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:38 +0x90
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 7 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:88 +0x118
//
// goroutine 82 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Withdraw(0x2)
// 	 [[ Cell [315] Line 3 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:69 +0x94
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 8 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:89 +0x124
//
// goroutine 83 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Deposit(0x4)
// 	 [[ Cell [182] Line 18 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:38 +0x90
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 7 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:88 +0x118
//
// goroutine 84 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Withdraw(0x2)
// 	 [[ Cell [315] Line 3 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:69 +0x94
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 8 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:89 +0x124
//
// goroutine 85 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Deposit(0x4)
// 	 [[ Cell [182] Line 18 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:38 +0x90
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 7 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:88 +0x118
//
// goroutine 86 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Withdraw(0x2)
// 	 [[ Cell [315] Line 3 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:69 +0x94
// ...
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 8 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:89 +0x124
//
// goroutine 181 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Deposit(0x4)
// 	 [[ Cell [182] Line 18 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:38 +0x90
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 7 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:88 +0x118
//
// goroutine 182 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Withdraw(0x2)
// 	 [[ Cell [315] Line 3 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:69 +0x94
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 8 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:89 +0x124
//
// goroutine 183 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Deposit(0x4)
// 	 [[ Cell [182] Line 18 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:38 +0x90
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 7 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:88 +0x118
//
// goroutine 184 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Withdraw(0x2)
// 	 [[ Cell [315] Line 3 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:69 +0x94
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 8 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:89 +0x124
//
// goroutine 185 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Deposit(0x4)
// 	 [[ Cell [182] Line 18 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:38 +0x90
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 7 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:88 +0x118
//
// goroutine 186 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Withdraw(0x2)
// 	 [[ Cell [315] Line 3 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:69 +0x94
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 8 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:89 +0x124
//
// goroutine 187 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Deposit(0x4)
// 	 [[ Cell [182] Line 18 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:38 +0x90
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 7 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:88 +0x118
//
// goroutine 188 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Withdraw(0x2)
// 	 [[ Cell [315] Line 3 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:69 +0x94
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 8 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:89 +0x124
//
// goroutine 189 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Deposit(0x4)
// 	 [[ Cell [182] Line 18 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:38 +0x90
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 7 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:88 +0x118
//
// goroutine 190 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Withdraw(0x2)
// 	 [[ Cell [315] Line 3 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:69 +0x94
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 8 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:89 +0x124
//
// goroutine 191 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Deposit(0x4)
// 	 [[ Cell [182] Line 18 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:38 +0x90
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 7 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:88 +0x118
//
// goroutine 192 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Withdraw(0x2)
// 	 [[ Cell [315] Line 3 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:69 +0x94
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 8 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:89 +0x124
//
// goroutine 193 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Deposit(0x4)
// 	 [[ Cell [182] Line 18 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:38 +0x90
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 7 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:88 +0x118
//
// goroutine 194 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Withdraw(0x2)
// 	 [[ Cell [315] Line 3 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:69 +0x94
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 8 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:89 +0x124
//
// goroutine 195 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Deposit(0x4)
// 	 [[ Cell [182] Line 18 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:38 +0x90
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 7 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:88 +0x118
//
// goroutine 196 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Withdraw(0x2)
// 	 [[ Cell [315] Line 3 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:69 +0x94
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 8 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:89 +0x124
//
// goroutine 197 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Deposit(0x4)
// 	 [[ Cell [182] Line 18 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:38 +0x90
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 7 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:88 +0x118
//
// goroutine 198 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Withdraw(0x2)
// 	 [[ Cell [315] Line 3 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:69 +0x94
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 8 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:89 +0x124
//
// goroutine 199 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Deposit(0x4)
// 	 [[ Cell [182] Line 18 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:38 +0x90
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 7 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:88 +0x118
//
// goroutine 200 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Withdraw(0x2)
// 	 [[ Cell [315] Line 3 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:69 +0x94
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 8 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:89 +0x124
//
// goroutine 201 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Deposit(0x4)
// 	 [[ Cell [182] Line 18 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:38 +0x90
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 7 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:88 +0x118
//
// goroutine 202 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Withdraw(0x2)
// 	 [[ Cell [315] Line 3 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:69 +0x94
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 8 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:89 +0x124
//
// goroutine 203 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Deposit(0x4)
// 	 [[ Cell [182] Line 18 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:38 +0x90
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 7 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:88 +0x118
//
// goroutine 204 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Withdraw(0x2)
// 	 [[ Cell [315] Line 3 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:69 +0x94
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 8 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:89 +0x124
//
// goroutine 205 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Deposit(0x4)
// 	 [[ Cell [182] Line 18 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:38 +0x90
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 7 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:88 +0x118
//
// goroutine 206 [sync.Mutex.Lock]:
// sync.runtime_SemacquireMutex(0x0?, 0x0?, 0x0?)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/sema.go:95 +0x28
// sync.(*Mutex).lockSlow(0x102f661e8)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:173 +0x174
// sync.(*Mutex).Lock(...)
// 	/opt/homebrew/Cellar/go/1.23.1/libexec/src/sync/mutex.go:92
// main.Withdraw(0x2)
// 	 [[ Cell [315] Line 3 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:69 +0x94
// created by main.main in goroutine 1
// 	 [[ Cell [316] Line 8 ]] /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/main.go:89 +0x124
// exit status 2

// %%
import "sync"
var (
  mu sync.Mutex //guards balance
  balance int
)
func Withdraw(amount int) bool {
    mu.Lock()
    defer mu.Unlock()
    deposit(-amount)
    //time.Sleep(5 * time.Millisecond)
    if balance < 0 {
        deposit(amount)
        return false // insufficient funds
    }
    return true
}
func Deposit(amount int) {
    mu.Lock()
    defer mu.Unlock()
    deposit(amount)
}
func Balance() int {
    mu.Lock()
    defer mu.Unlock()
    return balance
}
// require the lock be held
func deposit(amount int) { balance += amount}

// %%
import ("time";"fmt")
import "sync"
var (
  mu sync.Mutex //guards balance
  balance int
)
%%
var n sync.WaitGroup
//done := make(chan struct{})
for i:=0; i<10; i++ {
    balance=200
    for j :=0; j<50; j++ {
        n.Add(1)
        go func() {
          Deposit(6)
          n.Done()
          //done <- struct{}{}
        }()
        n.Add(1)
        go func() {
          Withdraw(8)
          n.Done()
          //done <- struct{}{}
        }()
        
        //go Deposit(4)
        //go Withdraw(1)
    }
    n.Wait()
    //for i:= 0; i <200; i++ {
    //  <-done
    //}
    //time.Sleep(8500* time.Millisecond)
    fmt.Println("=",Balance())
}
// Out:
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100
// = 100

// %% [markdown]
// ## Read/Write Mutexes: sync.RWMutex
// * Multiple readers, single writer lock, provided with sync.RWMutex

// %%
import "sync"
var (
    mu sync.RWMutex
    balance int
)
func Deposit(amount int) {
    mu.Lock()
    balance = balance + amount
    mu.Unlock()
}

func Balance()int {
    mu.RLock()  // readers lock
    defer mu.RUnlock()
    return balance
}

// %%
import ("time";"fmt")
%%
//done := make(chan struct{})
for i:=0; i<10; i++ {
    balance=0
    for j :=0; j<100; j++ {
      go Deposit(2)
    }
    time.Sleep(100* time.Millisecond)
    fmt.Println("=",Balance())
}
// Out:
// = 200
// = 200
// = 200
// = 200
// = 200
// = 200
// = 200
// = 200
// = 200
// = 200

// %% [markdown]
// ## Memory Synchronization

// %%
%% GOMAXPROC=4
var x, y int

for i:=0; i< 20; i++ {
 x, y = 0,0
 go func(){
   x = 1                 // A1
   fmt.Print("y:",y," ") // A2
 }()

 go func(){
    y = 1    //B1
    //time.Sleep(1 * time.Millisecond)
    fmt.Print("x:",x," ")//B2
 }()
 time.Sleep(300 * time.Millisecond)
 fmt.Println("")
 
}
time.Sleep(500 * time.Millisecond)
// Out:
// x:0 y:1
// x:0 y:1
// x:0 y:1
// x:0 y:1
// x:0 y:1
// x:0 y:1
// x:0 y:1
// x:0 y:1
// x:0 y:1
// x:0 y:1
// x:0 y:1
// x:0 y:1
// x:0 y:1
// x:0 y:1
// x:0 y:1
// x:0 y:1
// x:0 y:1
// x:0 y:1
// x:0 y:1
// x:0 y:1

// %% [markdown]
// ## Lazy Initialization: sync.Once
// * Defer an expensive initialization step until the moment it is needed

// %%
//Lazy initialization 
import "image"
var icons map[string]image.Image
func loadIcon(string)image.Image
func loadIcons(){
    icons = map[string]image.Image {
        "spades.png": loadIcon("spades.png"),
        "hearts.png": loadIcon("hearts.png"),
        "diamonds.png":loadIcon("diamonds.png"),
        "clubs.png":   loadIcon("clubs.png"),
    }
}
// Not concurrency-safe
func Icon(name string) image.Image {
    if icons == nil {
        loadIcons() // one-time initialization
    }
    return icons[name]
}
// Out:
// <style>
// .gonb-err-location {
// 	background: var(--jp-err-color2);
// 	border-radius: 3px;
// 	border-style: dotted;
// 	border-width: 1px;
// 	border-color: var(--jp-border-color2);
// }
// .gonb-err-location:hover {
// 	border-width: 2px;
// 	border-style: solid;
// 	border-color: var(--jp-border-color2);
// }
// .gonb-err-context {
// 	display: none;
// }
// .gonb-err-location:hover + .gonb-err-context {
// 	background: var(--jp-dialog-background);
// 	border-radius: 3px;
// 	border-style: solid;
// 	border-width: 1px;
// 	border-color: var(--jp-border-color2);
// 	display: block;
// 	white-space: pre;
// 	font-family: monospace;
// }
// .gonb-err-line {
// 	border-radius: 3px;
// 	border-style: dotted;
// 	border-width: 1px;
// 	border-color: var(--jp-border-color2);
// 	background-color: var(--jp-rendermime-err-background);
// 	font-weight: bold;
// }
// .gonb-cell-line-info {
// 	background: var(--jp-layout-color2);
// 	color: #999;
// 	margin: 0.1em;
// 	border: 1px solid var(--jp-border-color1);
// 	padding-left: 0.2em;
// 	padding-right: 0.2em;
// }
// </style>
// <div class="lm-Widget p-Widget lm-Panel p-Panel jp-OutputArea-child">
// <div class="lm-Widget p-Widget jp-RenderedText jp-mod-trusted jp-OutputArea-output" data-mime-type="application/vnd.jupyter.stderr" style="font-family: monospace;">
//
//
// <span style="white-space: pre;"> # gonb_ace7377a</span>
//
// <br/>
//
// <span class="gonb-cell-line-info">Cell[168]: Line 4</span>
// <span class="gonb-err-location">./main.go:45:6: </span> missing function body
// <div class="gonb-err-context">
//
// func deposit(amount int) { balance += amount}
//
// <div class="gonb-err-line">func loadIcon(string)image.Image
// </div>
// func loadIcons(){
//
// </div>
//
// <br/>
//
//
// <span style="white-space: pre;"> </span>
//
// <br/>
//
// </div>
// failed to run "/opt/homebrew/bin/go build -o /var/folders/4d/tg201k8x6yb81f_lrvt4440m0000gn/T/gonb_ace7377a/gonb_ace7377a": exit status 1

// %%
//icons may not be nil, but the initialization is not complete
import "image"
var icons map[string]image.Image
func loadIcons() {
    icons = make(map[string]image.Image)
    icons["spades.png"] = loadIcon("spades.png")
    icons["hearts.png"] = loadIcon("hearts.png")
    icons["diamonds.png"]=loadIcon("diamonds.png")
    icons["clubs.png"] = loadIcon("clubs.png")
}

// %%
// concurrency safe, but expensive for only one goroutine can access Icon
import "sync"
import "image"
var mu sync.Mutex // guard Icons
var icons map[string]image.Image
func Icon(name string)image.Image {
    mu.Lock()
    defer mu.Unlock()
    if icons == nil {
        loadIcons()
    }
    return icons[name]
}

// %%
var mu sync.RWMutex // guards icons
var icons map[string]image.Image
// Concurrency-safe
func Icon(name string) image.Image {
    mu.RLock()
    if icons != nil {
        icon := icons[name]
        mu.RUnlock()
        return icon
    }
    mu.RUnlock()
    //acquire an exclusive lock
    mu.Lock()
    if icons == nil {
        loadIcons()
    }
    icon := icons[name]
    mu.Unlock()
    return icon
}

// %%
var loadIconsOnce sync.Once
var icons map[string]image.Image
//Concurrency-safe
func Icon(name string) image.Image {
    loadIconsOnce.Do(loadIcons)
    return icons[name]
}

// %% [markdown]
// ## The Race Detector

// %% [markdown]
// * Go runtime and toolchain are equipped with a dynamic analysis tool, the race detector
// * Add the -race flat to go build, go run, or go test command
//   * Record all accesses to shared variables that occurred during execution, along with the identify of the goroutinge that read or wrote the variable
//   * Record all synchronization events
//     * go statements, channel operations, and calls to (*sync.Mutex).Lock, (*sync.WaitGroup).wait, and so on.

// %% [markdown]
// ## Example: Concurrent Non-Blocking Cache

// %%
// Package memo  1 provides a concurrency-unsafe
// memoization of a function of type Func.
// Copyright © 2016 Alan A. A. Donovan & Brian W. Kernighan.
// License: https://creativecommons.org/licenses/by-nc-sa/4.0/

// See page 272.

//!+


//package memo

// A Memo caches the results of calling a Func.
type Memo struct {
	f     Func
	cache map[string]result
}

// Func is the type of the function to memoize.
type Func func(key string) (interface{}, error)

type result struct {
	value interface{}
	err   error
}

func New(f Func) *Memo {
	return &Memo{f: f, cache: make(map[string]result)}
}

// NOTE: not concurrency-safe!
func (memo *Memo) Get(key string) (interface{}, error) {
	res, ok := memo.cache[key]
	if !ok {
		res.value, res.err = memo.f(key)
		memo.cache[key] = res
	}
	return res.value, res.err
}

//!-

// %%
// Copyright © 2016 Alan A. A. Donovan & Brian W. Kernighan.
// License: https://creativecommons.org/licenses/by-nc-sa/4.0/

//package memo_test

import (
        "testing"

        "gopl.io/ch9/memo1"
        "gopl.io/ch9/memotest"
)

var httpGetBody = memotest.HTTPGetBody

func Test(t *testing.T) {
        m := memo.New(httpGetBody)
        memotest.Sequential(t, m)
}

// NOTE: not concurrency-safe!  Test fails.
func TestConcurrent(t *testing.T) {
        m := memo.New(httpGetBody)
        memotest.Concurrent(t, m)
}
%test -test.run=TestConcurrent -test.v
// Out:
// === RUN   TestConcurrent
// https://godoc.org, 722.8025ms, 32284 bytes
// https://godoc.org, 734.979084ms, 32284 bytes
// https://golang.org, 804.2175ms, 62384 bytes
// https://golang.org, 824.836917ms, 62384 bytes
// https://play.golang.org, 1.178015125s, 30043 bytes
// http://gopl.io, 1.32408575s, 4154 bytes
// http://gopl.io, 1.324773666s, 4154 bytes
// https://play.golang.org, 1.844244375s, 30043 bytes
// --- PASS: TestConcurrent (1.85s)
// PASS

// %%
!go test -run=TestConcurrent -race -v gopl.io/ch9/memo1
// Out:
// === RUN   TestConcurrent
// https://golang.org, 536.230708ms, 62384 bytes
// https://godoc.org, 559.077083ms, 32284 bytes
// ==================
// WARNING: DATA RACE
// Write at 0x00c000103140 by goroutine 26:
//   runtime.mapaccess2_faststr()
//       /opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/map_faststr.go:117 +0x42c
//   gopl.io/ch9/memo1.(*Memo).Get()
//       /Users/skhuang/course/go2024/pkg/mod/gopl.io@v0.0.0-20211004154805-1ae3ec64947b/ch9/memo1/memo.go:35 +0xdc
//   gopl.io/ch9/memotest.Concurrent.func1()
//       /Users/skhuang/course/go2024/pkg/mod/gopl.io@v0.0.0-20211004154805-1ae3ec64947b/ch9/memotest/memotest.go:93 +0xac
//   gopl.io/ch9/memotest.Concurrent.gowrap1()
//       /Users/skhuang/course/go2024/pkg/mod/gopl.io@v0.0.0-20211004154805-1ae3ec64947b/ch9/memotest/memotest.go:100 +0x54
//
// Previous write at 0x00c000103140 by goroutine 10:
//   runtime.mapaccess2_faststr()
//       /opt/homebrew/Cellar/go/1.23.1/libexec/src/runtime/map_faststr.go:117 +0x42c
//   gopl.io/ch9/memo1.(*Memo).Get()
//       /Users/skhuang/course/go2024/pkg/mod/gopl.io@v0.0.0-20211004154805-1ae3ec64947b/ch9/memo1/memo.go:35 +0xdc
//   gopl.io/ch9/memotest.Concurrent.func1()
//       /Users/skhuang/course/go2024/pkg/mod/gopl.io@v0.0.0-20211004154805-1ae3ec64947b/ch9/memotest/memotest.go:93 +0xac
//   gopl.io/ch9/memotest.Concurrent.gowrap1()
//       /Users/skhuang/course/go2024/pkg/mod/gopl.io@v0.0.0-20211004154805-1ae3ec64947b/ch9/memotest/memotest.go:100 +0x54
//
// Goroutine 26 (running) created at:
//   gopl.io/ch9/memotest.Concurrent()
//       /Users/skhuang/course/go2024/pkg/mod/gopl.io@v0.0.0-20211004154805-1ae3ec64947b/ch9/memotest/memotest.go:90 +0x60
//   gopl.io/ch9/memo1_test.TestConcurrent()
//       /Users/skhuang/course/go2024/pkg/mod/gopl.io@v0.0.0-20211004154805-1ae3ec64947b/ch9/memo1/memo_test.go:23 +0xd4
//   testing.tRunner()
//       /opt/homebrew/Cellar/go/1.23.1/libexec/src/testing/testing.go:1690 +0x184
//   testing.(*T).Run.gowrap1()
//       /opt/homebrew/Cellar/go/1.23.1/libexec/src/testing/testing.go:1743 +0x40
//
// Goroutine 10 (finished) created at:
//   gopl.io/ch9/memotest.Concurrent()
//       /Users/skhuang/course/go2024/pkg/mod/gopl.io@v0.0.0-20211004154805-1ae3ec64947b/ch9/memotest/memotest.go:90 +0x60
//   gopl.io/ch9/memo1_test.TestConcurrent()
//       /Users/skhuang/course/go2024/pkg/mod/gopl.io@v0.0.0-20211004154805-1ae3ec64947b/ch9/memo1/memo_test.go:23 +0xd4
//   testing.tRunner()
//       /opt/homebrew/Cellar/go/1.23.1/libexec/src/testing/testing.go:1690 +0x184
//   testing.(*T).Run.gowrap1()
//       /opt/homebrew/Cellar/go/1.23.1/libexec/src/testing/testing.go:1743 +0x40
// ==================
// ==================
// WARNING: DATA RACE
// Write at 0x00c0001080a8 by goroutine 26:
//   gopl.io/ch9/memo1.(*Memo).Get()
//       /Users/skhuang/course/go2024/pkg/mod/gopl.io@v0.0.0-20211004154805-1ae3ec64947b/ch9/memo1/memo.go:35 +0xec
//   gopl.io/ch9/memotest.Concurrent.func1()
//       /Users/skhuang/course/go2024/pkg/mod/gopl.io@v0.0.0-20211004154805-1ae3ec64947b/ch9/memotest/memotest.go:93 +0xac
//   gopl.io/ch9/memotest.Concurrent.gowrap1()
//       /Users/skhuang/course/go2024/pkg/mod/gopl.io@v0.0.0-20211004154805-1ae3ec64947b/ch9/memotest/memotest.go:100 +0x54
//
// Previous write at 0x00c0001080a8 by goroutine 10:
//   gopl.io/ch9/memo1.(*Memo).Get()
//       /Users/skhuang/course/go2024/pkg/mod/gopl.io@v0.0.0-20211004154805-1ae3ec64947b/ch9/memo1/memo.go:35 +0xec
//   gopl.io/ch9/memotest.Concurrent.func1()
//       /Users/skhuang/course/go2024/pkg/mod/gopl.io@v0.0.0-20211004154805-1ae3ec64947b/ch9/memotest/memotest.go:93 +0xac
//   gopl.io/ch9/memotest.Concurrent.gowrap1()
//       /Users/skhuang/course/go2024/pkg/mod/gopl.io@v0.0.0-20211004154805-1ae3ec64947b/ch9/memotest/memotest.go:100 +0x54
//
// Goroutine 26 (running) created at:
//   gopl.io/ch9/memotest.Concurrent()
//       /Users/skhuang/course/go2024/pkg/mod/gopl.io@v0.0.0-20211004154805-1ae3ec64947b/ch9/memotest/memotest.go:90 +0x60
//   gopl.io/ch9/memo1_test.TestConcurrent()
//       /Users/skhuang/course/go2024/pkg/mod/gopl.io@v0.0.0-20211004154805-1ae3ec64947b/ch9/memo1/memo_test.go:23 +0xd4
//   testing.tRunner()
//       /opt/homebrew/Cellar/go/1.23.1/libexec/src/testing/testing.go:1690 +0x184
//   testing.(*T).Run.gowrap1()
//       /opt/homebrew/Cellar/go/1.23.1/libexec/src/testing/testing.go:1743 +0x40
//
// Goroutine 10 (finished) created at:
//   gopl.io/ch9/memotest.Concurrent()
//       /Users/skhuang/course/go2024/pkg/mod/gopl.io@v0.0.0-20211004154805-1ae3ec64947b/ch9/memotest/memotest.go:90 +0x60
//   gopl.io/ch9/memo1_test.TestConcurrent()
//       /Users/skhuang/course/go2024/pkg/mod/gopl.io@v0.0.0-20211004154805-1ae3ec64947b/ch9/memo1/memo_test.go:23 +0xd4
//   testing.tRunner()
//       /opt/homebrew/Cellar/go/1.23.1/libexec/src/testing/testing.go:1690 +0x184
//   testing.(*T).Run.gowrap1()
//       /opt/homebrew/Cellar/go/1.23.1/libexec/src/testing/testing.go:1743 +0x40
// ==================
// https://godoc.org, 558.477834ms, 32284 bytes
// https://golang.org, 682.735084ms, 62384 bytes
// https://play.golang.org, 995.534333ms, 30043 bytes
// http://gopl.io, 1.134414584s, 4154 bytes
// http://gopl.io, 1.133921917s, 4154 bytes
// https://play.golang.org, 1.715928167s, 30043 bytes
//     testing.go:1399: race detected during execution of test
// --- FAIL: TestConcurrent (1.72s)
// FAIL
// FAIL	gopl.io/ch9/memo1	2.018s
// FAIL
// exit status 1

// %% [markdown]
// ### memo2 with sync.Mutex, but with no performance gains

// %%
// Package memo  2 provides a concurrency-safe memoization a function of
// type Func.  Concurrent requests are serialized by a Mutex.
// Copyright © 2016 Alan A. A. Donovan & Brian W. Kernighan.
// License: https://creativecommons.org/licenses/by-nc-sa/4.0/

// See page 275.


//package memo

import "sync"

// Func is the type of the function to memoize.
type Func func(string) (interface{}, error)

type result struct {
	value interface{}
	err   error
}

func New(f Func) *Memo {
	return &Memo{f: f, cache: make(map[string]result)}
}

//!+

type Memo struct {
	f     Func
	mu    sync.Mutex // guards cache
	cache map[string]result
}

// Get is concurrency-safe.
func (memo *Memo) Get(key string) (value interface{}, err error) {
	memo.mu.Lock() 
	res, ok := memo.cache[key]
	if !ok {
		res.value, res.err = memo.f(key)
		memo.cache[key] = res
	}
	memo.mu.Unlock()
	return res.value, res.err
}

//!-

// %%
!go test -run=TestConcurrent -race -v gopl.io/ch9/memo2
// Out:
// === RUN   TestConcurrent
// https://golang.org, 537.702708ms, 62384 bytes
// https://play.golang.org, 1.50080025s, 30043 bytes
// http://gopl.io, 2.648391291s, 4154 bytes
// https://golang.org, 2.648406334s, 62384 bytes
// https://godoc.org, 3.189773917s, 32284 bytes
// https://play.golang.org, 3.189775042s, 30043 bytes
// http://gopl.io, 3.189828292s, 4154 bytes
// https://godoc.org, 3.189836167s, 32284 bytes
// --- PASS: TestConcurrent (3.19s)
// PASS
// ok  	gopl.io/ch9/memo2	(cached)

// %%
// Package memo 3 provides a concurrency-safe memoization a function of
// type Func.  Requests for different keys run concurrently.
// Concurrent requests for the same key result in duplicate work.
// Copyright © 2016 Alan A. A. Donovan & Brian W. Kernighan.
// License: https://creativecommons.org/licenses/by-nc-sa/4.0/

// See page 276.


//package memo

import "sync"

type Memo struct {
	f     Func
	mu    sync.Mutex // guards cache
	cache map[string]result
}

type Func func(string) (interface{}, error)

type result struct {
	value interface{}
	err   error
}

func New(f Func) *Memo {
	return &Memo{f: f, cache: make(map[string]result)}
}

//!+

func (memo *Memo) Get(key string) (value interface{}, err error) {
	memo.mu.Lock()
	res, ok := memo.cache[key]
	memo.mu.Unlock()
	if !ok {
		res.value, res.err = memo.f(key)

		// Between the two critical sections, several goroutines
		// may race to compute f(key) and update the map.
		memo.mu.Lock()
		memo.cache[key] = res
		memo.mu.Unlock()
	}
	return res.value, res.err
}

//!-

// %%
!go test -run=TestConcurrent -race -v gopl.io/ch9/memo3
// Out:
// === RUN   TestConcurrent
// https://golang.org, 465.132708ms, 62384 bytes
// https://godoc.org, 480.300875ms, 32284 bytes
// https://godoc.org, 511.824458ms, 32284 bytes
// https://golang.org, 618.412375ms, 62384 bytes
// https://play.golang.org, 964.262084ms, 30043 bytes
// http://gopl.io, 974.156375ms, 4154 bytes
// http://gopl.io, 974.712292ms, 4154 bytes
// https://play.golang.org, 1.799054459s, 30043 bytes
// --- PASS: TestConcurrent (1.80s)
// PASS
// ok  	gopl.io/ch9/memo3	(cached)

// %%
// Package memo 4 provides a concurrency-safe memoization a function of
// a function.  Requests for different keys proceed in parallel.
// Concurrent requests for the same key block until the first completes.
// This implementation uses a Mutex.
// Copyright © 2016 Alan A. A. Donovan & Brian W. Kernighan.
// License: https://creativecommons.org/licenses/by-nc-sa/4.0/

// See page 276.

//package memo
type Func func(string) (interface{}, error)

type result struct {
	value interface{}
	err   error
}

//
type entry struct {
	res   result
	ready chan struct{} // closed when res is ready
}

func New(f Func) *Memo {
	return &Memo{f: f, cache: make(map[string]*entry)}
}

type Memo struct {
	f     Func
	mu    sync.Mutex // guards cache
	cache map[string]*entry
}

func (memo *Memo) Get(key string) (value interface{}, err error) {
	memo.mu.Lock()
	e := memo.cache[key]
	if e == nil {
		// This is the first request for this key.
		// This goroutine becomes responsible for computing
		// the value and broadcasting the ready condition.
		e = &entry{ready: make(chan struct{})}
		memo.cache[key] = e
		memo.mu.Unlock()

		e.res.value, e.res.err = memo.f(key)

		close(e.ready) // broadcast ready condition
	} else {
		// This is a repeat request for this key.
		memo.mu.Unlock()

		<-e.ready // wait for ready condition
	}
	return e.res.value, e.res.err
}

//!-

// %%
!go test -run=TestConcurrent -race -v gopl.io/ch9/memo4
// Out:
// === RUN   TestConcurrent
// https://golang.org, 496.159084ms, 62384 bytes
// https://golang.org, 496.019708ms, 62384 bytes
// https://godoc.org, 813.121708ms, 32284 bytes
// https://godoc.org, 812.712166ms, 32284 bytes
// https://play.golang.org, 1.022265917s, 30043 bytes
// https://play.golang.org, 1.022265292s, 30043 bytes
// http://gopl.io, 1.303557542s, 4154 bytes
// http://gopl.io, 1.303125625s, 4154 bytes
// --- PASS: TestConcurrent (1.30s)
// PASS
// ok  	gopl.io/ch9/memo4	(cached)

// %%
// Package memo 5 provides a concurrency-safe non-blocking memoization
// of a function.  Requests for different keys proceed in parallel.
// Concurrent requests for the same key block until the first completes.
// This implementation uses a monitor goroutine.
// Copyright © 2016 Alan A. A. Donovan & Brian W. Kernighan.
// License: https://creativecommons.org/licenses/by-nc-sa/4.0/

// See page 278.

//package memo

//!+Func

// Func is the type of the function to memoize.
type Func func(key string) (interface{}, error)

// A result is the result of calling a Func.
type result struct {
	value interface{}
	err   error
}

type entry struct {
	res   result
	ready chan struct{} // closed when res is ready
}

//!-Func

//!+get

// A request is a message requesting that the Func be applied to key.
type request struct {
	key      string
	response chan<- result // the client wants a single result
}

type Memo struct{ requests chan request }

// New returns a memoization of f.  Clients must subsequently call Close.
func New(f Func) *Memo {
	memo := &Memo{requests: make(chan request)}
	go memo.server(f)
	return memo
}

func (memo *Memo) Get(key string) (interface{}, error) {
	response := make(chan result)
	memo.requests <- request{key, response}
	res := <-response
	return res.value, res.err
}

func (memo *Memo) Close() { close(memo.requests) }

//!-get

//!+monitor

func (memo *Memo) server(f Func) {
	cache := make(map[string]*entry)
	for req := range memo.requests {
		e := cache[req.key]
		if e == nil {
			// This is the first request for this key.
			e = &entry{ready: make(chan struct{})}
			cache[req.key] = e
			go e.call(f, req.key) // call f(key)
		}
		go e.deliver(req.response)
	}
}

func (e *entry) call(f Func, key string) {
	// Evaluate the function.
	e.res.value, e.res.err = f(key)
	// Broadcast the ready condition.
	close(e.ready)
}

func (e *entry) deliver(response chan<- result) {
	// Wait for the ready condition.
	<-e.ready
	// Send the result to the client.
	response <- e.res
}

//!-monitor

// %%
!go test -run=TestConcurrent -race -v gopl.io/ch9/memo5
// Out:
// === RUN   TestConcurrent
// https://golang.org, 578.723125ms, 62384 bytes
// https://golang.org, 578.574375ms, 62384 bytes
// https://godoc.org, 711.614ms, 32284 bytes
// https://godoc.org, 712.00375ms, 32284 bytes
// https://play.golang.org, 1.01674275s, 30043 bytes
// https://play.golang.org, 1.017377s, 30043 bytes
// http://gopl.io, 1.265006959s, 4154 bytes
// http://gopl.io, 1.265144875s, 4154 bytes
// --- PASS: TestConcurrent (1.27s)
// PASS
// ok  	gopl.io/ch9/memo5	2.603s

// %% [markdown]
// ## Goroutines and Threads

// %% [markdown]
// ### Growable Stacks
// * a goroutine start with a small stack, typically 2KB
// * a goroutine's stack is not fixed
//   * it grows and shrinks as needed, with the limit of 1GB

// %% [markdown]
// ### Groroutine Scheduling
// * The Go runtime contains its own scheduler using a technique known as m:n scheduling
//     * it multiplexes (or schedules) m go routines on n OS threads
//     * the Go scheduler is not invoked periodically by a hardware timer
//       * implicitly by certain Go language constructs
//         * time.Sleep or blocks in a channel or mutex operation

// %% [markdown]
// ### GOMAXPROCS
// * GOMAXPROCS is the n in m:n scheduling

// %%
import "fmt"
%% GOMAXPROC=4
for i:=1;i<100;i++ {
    go fmt.Print(0)
    fmt.Print(1)
}
fmt.Println()
// GOMAXPROC=1 go run hacker-cliche.go
// GOMAXPROC=2 go run hacker-cliche.go
// Out:
// 111111111100000001111111001000001111100000111000110000111111000011111100000000111110000111111100011111100000000000000111111111010000111110000111100000001110011111100000000111111110000000011111

// %%
!pwd
!GOMAXPROC=1 go run hacker-cliche.go
!GOMAXPROC=2 go run hacker-cliche.go
!GOMAXPROC=3 go run hacker-cliche.go
!GOMAXPROC=4 go run hacker-cliche.go
// Out:
// /Users/skhuang/course/go2024/go2024/ch9
// 0111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111
// 1111111111111111111111000001000000000001111111111111111111111111111111111111111111111111111111111111111111111111111
// 1111111100000000011110111111111111111111111111111111111111111111111111111111111111111111111111111111111111111
// 111111111111111111000010100000011111100111000000000111111111111100000000111111110000000000000000001111111111111111111110011111111110000100000010000000000000000000000001111111111111111

// %% [markdown]
// ### Goroutines Have No Identify
// * Goroutines have no notion of identity that is accessible to the programmer
// * Go encourages a simpler style of programming in which parameters that affect the behavior of a function are explicit
